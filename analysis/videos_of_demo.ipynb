# %%
import numpy as np
from PIL import Image, ImageShow
from matplotlib import pyplot as plt
from IPython import display

# %%
x = np.load('../data/demo_reach_cuboid_00FF00_camera32.npz', allow_pickle=True)
for k in x.keys():
    print(k)
print(len(x['demo_action_sequences']))
# Out:
# demo_image_sequences
# demo_action_sequences
# step_marker
# 373

# %%
x_data = x['demo_image_sequences']
print(x_data.shape, x_data.min(), x_data.max())
marker = x['step_marker']
print([marker[i+1] - marker[i] for i in range(len(marker) -1)])
# Out:
# (373, 32, 32, 3) 0 247
# [116, 121, 136]

# %%
for i in range(3):
    print(x_data[:,:,:,i].min(), x_data[:,:,:,i].max())
# Out:
# 0 218
# 20 247
# 0 209

# %%
imgs = [Image.fromarray(i) for i in x_data]
print(len(imgs))
# Out:
# 373

# %%
for i in range(len(imgs)):
    plt.figure(i)
    plt.imshow(x_data[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /vol/bitbucket/hzd21/msc_project/analysis/videos_of_demo.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/vol/bitbucket/hzd21/msc_project/analysis/videos_of_demo.ipynb#ch0000006?line=0'>1</a> for i in range(len(imgs)):
#       <a href='vscode-notebook-cell:/vol/bitbucket/hzd21/msc_project/analysis/videos_of_demo.ipynb#ch0000006?line=1'>2</a>     plt.figure(i)
#       <a href='vscode-notebook-cell:/vol/bitbucket/hzd21/msc_project/analysis/videos_of_demo.ipynb#ch0000006?line=2'>3</a>     plt.imshow(xint[3])
#
# NameError: name 'imgs' is not defined

# %%
imgs[0].save('../data/yellow_test.gif', save_all=True, append_images=imgs[1:])

# %%
display.Image('../data/yellow_test.gif')

# %%
y = x['demo_action_sequences']

# %%
plt.plot(y)
plt.legend('xyz')
plt.grid()

# %%
np.random.uniform(1,1, 2)
# Out:
# array([1., 1.])

# %%
init_conf = np.load('../data/scene_setups_22_06_22_14_57_29.npz', allow_pickle=True)
init_imgs = init_conf['images']
print(init_imgs.shape, init_imgs.min(), init_imgs.max())
xint = np.array(init_imgs * 255, dtype=np.uint8)
print(xint.shape)
# Out:
# (3, 64, 64, 3) 0.0 0.4
# (3, 64, 64, 3)

# %%
for k in init_conf.keys():
    print(k)
# Out:
# joint_angles
# obj_poses
# images

# %%
imgs = [Image.fromarray(i) for i in xint]
print(len(imgs))
# Out:
# 3

# %%
imgs[0].save('../data/init_poses.gif', save_all=True, append_images=imgs[1:])

# %%
display.Image('../data/init_poses.gif')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-5918ac865315> in <module>
# ----> 1 display.Image('../data/init_poses.gif')
#
# AttributeError: 'function' object has no attribute 'Image'
