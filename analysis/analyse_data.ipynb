# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.spatial.transform.rotation import Rotation

# %%
log = dict(np.load('bc_log.npz', allow_pickle=True))['arr_0']

# %%
plt.plot(log.all()['x_current'])
plt.plot(log.all()['v'], '.')
# Out:
# [<matplotlib.lines.Line2D at 0x7f79e5605ac0>,
#  <matplotlib.lines.Line2D at 0x7f79e5605b20>,
#  <matplotlib.lines.Line2D at 0x7f79e5605bb0>,
#  <matplotlib.lines.Line2D at 0x7f79e5605c70>,
#  <matplotlib.lines.Line2D at 0x7f79e557da30>,
#  <matplotlib.lines.Line2D at 0x7f79e5605d30>,
#  <matplotlib.lines.Line2D at 0x7f79e5605e20>]

# %%
# Out:
# [<matplotlib.lines.Line2D at 0x7f79e5171f40>,
#  <matplotlib.lines.Line2D at 0x7f79e517e070>,
#  <matplotlib.lines.Line2D at 0x7f79e517e130>,
#  <matplotlib.lines.Line2D at 0x7f79e517e1f0>,
#  <matplotlib.lines.Line2D at 0x7f79e517e2b0>,
#  <matplotlib.lines.Line2D at 0x7f79e517e370>,
#  <matplotlib.lines.Line2D at 0x7f79e517e430>]

# %%
q = [1.2246468e-16,  0.0000000e+00,  0.0000000e+00, -1.0000000e+00]
r = Rotation.from_quat(q)

# %%
r.as_euler('XYZ', degrees=True)
# Out:
# array([0., 0., 0.])

# %%
e = [360, 360, 360]
r = Rotation.from_euler('XYZ', e, degrees=True)

# %%
r.as_quat()
# Out:
# array([ 1.2246468e-16,  1.2246468e-16,  1.2246468e-16, -1.0000000e+00])

# %%
data = np.load('../data/demo_reach_object_22_06_22_18_52_19.npz', allow_pickle=True)
for k in data.keys():
    print(k)
print(len(data['demo_action_sequences']))
# Out:
# demo_image_sequences
# demo_action_sequences
# demo_robot_state_sequences
# demo_control_input_sequences
# 600

# %%
y = data['demo_action_sequences']

# %%
y.shape
# Out:
# (600,)

# %%
y0 = y[0]
plt.plot(y0[:, :3])
# Out:
# [<matplotlib.lines.Line2D at 0x7fc6a246b370>,
#  <matplotlib.lines.Line2D at 0x7fc6a246b460>,
#  <matplotlib.lines.Line2D at 0x7fc6a246b520>]

# %%
plt.plot(y0[:, 3:6])
# Out:
# [<matplotlib.lines.Line2D at 0x7fc6a24e18b0>,
#  <matplotlib.lines.Line2D at 0x7fc6a24e19a0>,
#  <matplotlib.lines.Line2D at 0x7fc6a24e1a60>]

# %%
quat = y0[:, 3:]
quat.shape
# Out:
# (55, 4)

# %%
r = Rotation.from_quat(quat)
euler = r.as_euler('XYZ')
euler.shape
# Out:
# (55, 3)

# %%
plt.plot(-euler)
# Out:
# [<matplotlib.lines.Line2D at 0x7fc6a2cfddf0>,
#  <matplotlib.lines.Line2D at 0x7fc6a2cfdee0>,
#  <matplotlib.lines.Line2D at 0x7fc6a2cfdfa0>]

# %%
plt.plot(y0[:, 3:6]*2)
plt.plot(-euler)
plt.grid()

# %%
plt.plot((2*y0[:, 3:6] + euler)**2)
plt.grid()
plt.yscale('log')

# %%
angles = np.array([0.01, 0.007, -0.0067])
r = Rotation.from_euler('xyz', angles)
r.as_quat(), angles/2
# Out:
# (array([ 0.00501165,  0.00348318, -0.00336743,  0.99997571]),
#  array([ 0.005  ,  0.0035 , -0.00335]))

# %%
angles = np.array([189, 1, 190])
r = Rotation.from_euler('xyz', angles, degrees=True)
r.as_euler('xyz', degrees=True)
# Out:
# array([-171.,    1., -170.])

# %%
np.prod([6, 9, 2])
# Out:
# 108

# %%
64*64*3*512
